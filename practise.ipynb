# %%
import numpy as np  
import pandas as pd  
import os
import matplotlib.pyplot as plt  
% matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\hemanjali\\Downloads\\mypython\\ipython'

# %%
df = pd.read_csv("C:/Users/hemanjali/Downloads/mypython/ipython/datasets/timesMergedDatascientistData.csv") 
# i am reading all datascientists data which is in some other directory or path

# %%
len(df)
# Out:
# 954

# %%
df.head()

# %%
df.boxplot(by ='STATE', column =['NOC'], grid = True)

# %% [markdown]
# ## one more on iris

# %%
data = pd.read_csv("C:/Users/hemanjali/Downloads/mypython/ipython/datasets/iris.csv")

# %%
data.head(10)
# Out:
#    sepal length  sepal width  petal length   petal width        class
# 0           5.1          3.5           1.4           0.2  Iris-setosa
# 1           4.9          3.0           1.4           0.2  Iris-setosa
# 2           4.7          3.2           1.3           0.2  Iris-setosa
# 3           4.6          3.1           1.5           0.2  Iris-setosa
# 4           5.0          3.6           1.4           0.2  Iris-setosa
# 5           5.4          3.9           1.7           0.4  Iris-setosa
# 6           4.6          3.4           1.4           0.3  Iris-setosa
# 7           5.0          3.4           1.5           0.2  Iris-setosa
# 8           4.4          2.9           1.4           0.2  Iris-setosa
# 9           4.9          3.1           1.5           0.1  Iris-setosa

# %%
data["sepal length"].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal length, dtype: float64

# %% [markdown]
# # some violin plot

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize =(9, 7)) 
sns.violinplot( ax = ax, y = data["sepal length"] )

# %%
fig, ax = plt.subplots(figsize =(9, 7)) 
sns.violinplot(ax = ax,  y = data["sepal width"] )

# %%
fig, ax = plt.subplots(figsize =(9, 7)) 
sns.violinplot(ax = ax,  y = data["petal length"] )

# %%
fig, ax = plt.subplots(figsize =(9, 7)) 
sns.violinplot(ax = ax,  y = data["petal length"] )
