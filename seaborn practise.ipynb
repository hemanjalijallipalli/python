# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x =['sun', 'mon', 'fri', 'sat', 'tue', 'wed', 'thu'] 
y =[5, 6.7, 4, 6, 2, 4.9, 1.8]
first =sns.stripplot(x, y)
first.set(xlabel ='weekday', ylabel ='Amount_spend') 
plt.title('My first graph'); 
plt.show()

# %%
### or else italic font

# %% [markdown]
# ## can also do this way

# %% [markdown]
# # try this big font guys

# %% [markdown]
# **whats this does  bold dear

# %%
import numpy as np
a=np.arange(20)
b=np.array([33,44,5,5,5,5,2,4,4,3,3,3,3,3,5,5,5])
a=sns.stripplot(x,y)
plt.xlabel('something')
plt.ylabel('nothing')
plt.title('gross')
# Out:
# Text(0.5,1,'gross')

# %%
sns.set(style ="whitegrid") 
iris = sns.load_dataset('iris'); 
ax = sns.stripplot(x = 'species', y = 'sepal_length', data = iris); 
plt.title('Graph')
# Out:
# Text(0.5,1,'Graph')

# %%
sns.set(style ="darkgrid") 
iris1 = sns.load_dataset('iris'); 
axe = sns.stripplot(x = 'species', y = 'sepal_length', data = iris1); 
plt.title('Graphs')
# Out:
# Text(0.5,1,'Graphs')

# %%
first = sns.swarmplot(x = 'species', y = 'sepal_length', data = iris);
